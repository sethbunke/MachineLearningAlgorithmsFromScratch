# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.model_selection import train_test_split


from sklearn.datasets import load_boston, load_iris

matplotlib.rcParams['figure.figsize'] = (0.89 * 12, 6)
plt.style.use('fivethirtyeight')
# %matplotlib inline

#https://github.com/ColCarroll/working_ml/blob/master/working_ml.ipynbs

# %%
boston = load_boston()
boston_frame = pd.DataFrame(boston.data, columns=boston.feature_names)

# %%
sns.pairplot(boston_frame);

# %%
train_X, test_X, train_y, test_y = train_test_split(boston.data, boston.target, test_size=100)

# %%
reg = LinearRegression().fit(train_X, train_y)

# %%
line = np.linspace(train_y.min(), train_y.max())
plt.plot(line, line, label='Perfect fit')
plt.plot(train_y, reg.predict(train_X), 'o')
plt.legend()
plt.title('Linear performance on training set')
plt.xlabel('True House Price ($1k)')
plt.ylabel('Estimated House Price ($1k)');

# %%
line = np.linspace(test_y.min(), test_y.max())
plt.plot(line, line, label='Perfect fit')
plt.plot(test_y, reg.predict(test_X), 'o')
plt.legend()
plt.title('Linear performance on test set')
plt.xlabel('True House Price ($1k)')
plt.ylabel('Estimated House Price ($1k)');

# %%
def graph_linear_regression_line(model, test_X, test_y, graph_label, graph_title, x_label, y_label, graph_char='x'):
    import numpy as np
    line = np.linspace(test_y.min(), test_y.max())
    plt.plot(line, line, label=graph_label)
    plt.plot(test_y, model.predict(test_X), graph_char)
    plt.legend()
    plt.title(graph_title)
    plt.xlabel(x_label)
    plt.ylabel(y_label);

# %%
graph_linear_regression_line(reg, test_X, test_y, "Fit Line", "Linear Regression", "Estimated Price", "Actual Price", 'o')

# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt

dataframe = pd.read_fwf('brain_body.txt')
x_values = dataframe[['Brain']]
y_values = dataframe[['Body']]

body_regression = linear_model.LinearRegression()
body_regression.fit(x_values, y_values)

plt.scatter(x_values, y_values)
plt.plot(x_values, body_regression.predict(x_values))
plt.show()

# %%
graph_linear_regression_line(body_regression, x_values, y_values, "Fit Line", "Linear Regression", "Estimated Price", "Actual Price", 'o')
